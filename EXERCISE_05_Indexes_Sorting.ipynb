# %% [markdown]
# # Indexes & Sorting Exercise

# %% [markdown]
# ## Part 1
# * Import the `pokemon.csv` dataset
# * Make the Name column the index (do it in place on the original DataFrame!)

# %%
import pandas as pd
import numpy as np

# %%
dp = pd.read_csv("data/pokemon.csv")

# %%
dp.head()
# Out:
#    Num        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3    Venusaur  Grass  Poison    525  80      82       83      100
# 3    4  Charmander   Fire     NaN    309  39      52       43       60
# 4    5  Charmeleon   Fire     NaN    405  58      64       58       80
#
#    Sp. Def  Speed  Stage  Legendary
# 0       65     45      1      False
# 1       80     60      2      False
# 2      100     80      3      False
# 3       50     65      1      False
# 4       65     80      2      False

# %%
dp.set_index('Name',inplace=True)

# %%
dp.head(2)
# Out:
#            Num Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur    1  Grass  Poison    318  45      49       49       65       65
# Ivysaur      2  Grass  Poison    405  60      62       63       80       80
#
#            Speed  Stage  Legendary
# Name
# Bulbasaur     45      1      False
# Ivysaur       60      2      False

# %% [markdown]
# ## Part 2
# * Sort the pokemon by the Attack column, from highest to lowest
# * Sort the pokemon by the Num column, from lowest to highest, in place.
# * Sort the pokemon by the Total column AND the Attack column (in that order!) from highest to lowest
# * Sort the pokemon by their index, from lowest to highest, in place (From A-Z)

# %%
dp.sort_values('Attack', ascending=False)
# Out:
#            Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Dragonite  149    Dragon  Flying    600   91     134       95      100
# Rhydon     112    Ground    Rock    485  105     130      120       45
# Flareon    136      Fire     NaN    525   65     130       60       95
# Machamp     68  Fighting     NaN    505   90     130       80       65
# Kingler     99     Water     NaN    475   55     130      115       50
# ...        ...       ...     ...    ...  ...     ...      ...      ...
# Kakuna      14       Bug  Poison    205   45      25       50       25
# Abra        63   Psychic     NaN    310   25      20       15      105
# Metapod     11       Bug     NaN    205   50      20       55       25
# Magikarp   129     Water     NaN    200   20      10       55       15
# Chansey    113    Normal     NaN    450  250       5        5       35
#
#            Sp. Def  Speed  Stage  Legendary
# Name
# Dragonite      100     80      3      False
# Rhydon          45     40      2      False
# Flareon        110     65      2      False
# Machamp         85     55      3      False
# Kingler         50     75      2      False
# ...            ...    ...    ...        ...
# Kakuna          25     35      2      False
# Abra            55     90      1      False
# Metapod         25     30      2      False
# Magikarp        20     80      1      False
# Chansey        105     50      1      False
#
# [151 rows x 12 columns]

# %%
dp.sort_values('Num', ascending=True,inplace=True)

# %%
dp.sort_values(['Attack','Total'], ascending=False)
# Out:
#            Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Dragonite  149    Dragon  Flying    600   91     134       95      100
# Flareon    136      Fire     NaN    525   65     130       60       95
# Machamp     68  Fighting     NaN    505   90     130       80       65
# Rhydon     112    Ground    Rock    485  105     130      120       45
# Kingler     99     Water     NaN    475   55     130      115       50
# ...        ...       ...     ...    ...  ...     ...      ...      ...
# Kakuna      14       Bug  Poison    205   45      25       50       25
# Abra        63   Psychic     NaN    310   25      20       15      105
# Metapod     11       Bug     NaN    205   50      20       55       25
# Magikarp   129     Water     NaN    200   20      10       55       15
# Chansey    113    Normal     NaN    450  250       5        5       35
#
#            Sp. Def  Speed  Stage  Legendary
# Name
# Dragonite      100     80      3      False
# Flareon        110     65      2      False
# Machamp         85     55      3      False
# Rhydon          45     40      2      False
# Kingler         50     75      2      False
# ...            ...    ...    ...        ...
# Kakuna          25     35      2      False
# Abra            55     90      1      False
# Metapod         25     30      2      False
# Magikarp        20     80      1      False
# Chansey        105     50      1      False
#
# [151 rows x 12 columns]

# %%
dp.sort_index(inplace=True)

# %%
dp.head()
# Out:
#             Num   Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Abra         63  Psychic     NaN    310  25      20       15      105
# Aerodactyl  142     Rock  Flying    515  80     105       65       60
# Alakazam     65  Psychic     NaN    500  55      50       45      135
# Arbok        24   Poison     NaN    438  60      85       69       65
# Arcanine     59     Fire     NaN    555  90     110       80      100
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# Abra             55     90      1      False
# Aerodactyl       75    130      1      False
# Alakazam         95    120      3      False
# Arbok            79     80      2      False
# Arcanine         80     95      2      False

# %% [markdown]
# ## Part 3
#
# * Find the average Speed of the 10 pokemon with the highest Speed.
# * Of the top 20 pokemon with the highest Attack values, what is the most common value for "Type 1"?

# %%
highest_pk = dp.sort_values('Speed',ascending=False)

# %%
Top10_highest_pk= highest_pk.head(10)

# %%
Top10_highest_pk
# Out:
#             Num    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Electrode   101  Electric      NaN    480   60      50       70       80
# Aerodactyl  142      Rock   Flying    515   80     105       65       60
# Jolteon     135  Electric      NaN    525   65      65       60      110
# Mewtwo      150   Psychic      NaN    680  106     110       90      154
# Alakazam     65   Psychic      NaN    500   55      50       45      135
# Dugtrio      51    Ground      NaN    405   35      80       50       50
# Starmie     121     Water  Psychic    520   60      75       85      100
# Persian      53    Normal      NaN    440   65      70       60       65
# Raichu       26  Electric      NaN    485   60      90       55       90
# Tauros      128    Normal      NaN    490   75     100       95       40
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# Electrode        80    140      2      False
# Aerodactyl       75    130      1      False
# Jolteon          95    130      2      False
# Mewtwo           90    130      1       True
# Alakazam         95    120      3      False
# Dugtrio          70    120      2      False
# Starmie          85    115      2      False
# Persian          65    115      2      False
# Raichu           80    110      2      False
# Tauros           70    110      1      False

# %%
mean_speed = Top10_highest_pk['Speed'].mean()
mean_speed
# Out:
# 122.0

# %%
highest_Attack = dp.sort_values('Attack',ascending=False)
Top10_highest_Attack= highest_Attack.head(20)

# %%
Top10_highest_Attack
# Out:
#             Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Dragonite   149    Dragon  Flying    600   91     134       95      100
# Rhydon      112    Ground    Rock    485  105     130      120       45
# Flareon     136      Fire     NaN    525   65     130       60       95
# Kingler      99     Water     NaN    475   55     130      115       50
# Machamp      68  Fighting     NaN    505   90     130       80       65
# Pinsir      127       Bug     NaN    500   65     125      100       55
# Gyarados    130     Water  Flying    540   95     125       79       60
# Hitmonlee   106  Fighting     NaN    455   50     120       53       35
# Golem        76      Rock  Ground    495   80     120      130       55
# Kabutops    141      Rock   Water    495   60     115      105       65
# Arcanine     59      Fire     NaN    555   90     110       80      100
# Mewtwo      150   Psychic     NaN    680  106     110       90      154
# Dodrio       85    Normal  Flying    460   60     110       70       60
# Scyther     123       Bug  Flying    500   70     110       80       55
# Snorlax     143    Normal     NaN    540  160     110       65       65
# Primeape     57  Fighting     NaN    455   65     105       60       60
# Muk          89    Poison     NaN    500  105     105       75       65
# Krabby       98     Water     NaN    325   30     105       90       25
# Hitmonchan  107  Fighting     NaN    455   50     105       79       35
# Aerodactyl  142      Rock  Flying    515   80     105       65       60
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# Dragonite       100     80      3      False
# Rhydon           45     40      2      False
# Flareon         110     65      2      False
# Kingler          50     75      2      False
# Machamp          85     55      3      False
# Pinsir           70     85      1      False
# Gyarados        100     81      2      False
# Hitmonlee       110     87      1      False
# Golem            65     45      3      False
# Kabutops         70     80      2      False
# Arcanine         80     95      2      False
# Mewtwo           90    130      1       True
# Dodrio           60    100      2      False
# Scyther          80    105      1      False
# Snorlax         110     30      1      False
# Primeape         70     95      2      False
# Muk             100     50      2      False
# Krabby           25     50      1      False
# Hitmonchan      110     76      1      False
# Aerodactyl       75    130      1      False

# %%
highest_Attack['Type 1'].mode()
# Out:
# 0    Water
# Name: Type 1, dtype: object

# %% [markdown]
# ## Part 4
# * Retrieve the row with the index label of "Diglett"
# * Retrieve the rows for the two fox-like Pokemon: Eevee and Vulpix
# * Make sure your DataFrame is sorted by index (A-Z).  Retrieve the rows from Charizard to Charmeleon.  You should get three rows back.
# * Retrieve the 30th, 40th, and 50th rows by position.

# %%
row_diglett = dp.loc['Diglett']
row_diglett
# Out:
# Num              50
# Type 1       Ground
# Type 2          NaN
# Total           265
# HP               10
# Attack           55
# Defense          25
# Sp. Atk          35
# Sp. Def          45
# Speed            95
# Stage             1
# Legendary     False
# Name: Diglett, dtype: object

# %%
fox_like_pokemon = dp.loc[['Eevee', 'Vulpix']]
fox_like_pokemon
# Out:
#         Num  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Eevee   133  Normal    NaN    325  55      55       50       45       65
# Vulpix   37    Fire    NaN    299  38      41       40       50       65
#
#         Speed  Stage  Legendary
# Name
# Eevee      55      1      False
# Vulpix     65      1      False

# %%
selected_rows = dp.loc['Charizard':'Charmeleon']
selected_rows
# Out:
#             Num Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Charizard     6   Fire  Flying    534  78      84       78      109       85
# Charmander    4   Fire     NaN    309  39      52       43       60       50
# Charmeleon    5   Fire     NaN    405  58      64       58       80       65
#
#             Speed  Stage  Legendary
# Name
# Charizard     100      3      False
# Charmander     65      1      False
# Charmeleon     80      2      False

# %%
selected_position = dp.iloc[[29, 39, 49]]
selected_position
# Out:
#            Num  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Dugtrio     51  Ground     NaN    405  35      80       50       50       70
# Gastly      92   Ghost  Poison    310  30      35       30      100       35
# Growlithe   58    Fire     NaN    350  55      70       45       70       50
#
#            Speed  Stage  Legendary
# Name
# Dugtrio      120      2      False
# Gastly        80      1      False
# Growlithe     60      1      False

# %% [markdown]
# ## Part 5
# * Retrieve the rows of the fish-like Pokemon.  Use this list to make it easier:
# ```py
# fish_pokemon = ["Magikarp", "Goldeen","Horsea", "Seaking", "Seadra","Gyarados"]
# ```

# %%
fish_pokemon = ["Magikarp", "Goldeen","Horsea", "Seaking", "Seadra","Gyarados"]
fish_like_Pokemon = dp[dp.index.isin(fish_pokemon)]

# %%
fish_like_Pokemon
# Out:
#           Num Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Goldeen   118  Water     NaN    320  45      67       60       35       50
# Gyarados  130  Water  Flying    540  95     125       79       60      100
# Horsea    116  Water     NaN    295  30      40       70       70       25
# Magikarp  129  Water     NaN    200  20      10       55       15       20
# Seadra    117  Water     NaN    440  55      65       95       95       45
# Seaking   119  Water     NaN    450  80      92       65       65       80
#
#           Speed  Stage  Legendary
# Name
# Goldeen      63      1      False
# Gyarados     81      2      False
# Horsea       60      1      False
# Magikarp     80      1      False
# Seadra       85      2      False
# Seaking      68      2      False

# %% [markdown]
# ## Part 6
#
# * Create this bar chart that shows the Attack values for the above fish-like Pokemon.  Pay attention to the sorting!!
# <div>
# <img src="attachment:fish_plot.png" width="400"/>
# </div>

# %%
import matplotlib.pyplot as plt
sorted_Attack = fish_like_Pokemon.sort_values('Attack')

# %%
sorted_Attack
# Out:
#           Num Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Magikarp  129  Water     NaN    200  20      10       55       15       20
# Horsea    116  Water     NaN    295  30      40       70       70       25
# Seadra    117  Water     NaN    440  55      65       95       95       45
# Goldeen   118  Water     NaN    320  45      67       60       35       50
# Seaking   119  Water     NaN    450  80      92       65       65       80
# Gyarados  130  Water  Flying    540  95     125       79       60      100
#
#           Speed  Stage  Legendary
# Name
# Magikarp     80      1      False
# Horsea       60      1      False
# Seadra       85      2      False
# Goldeen      63      1      False
# Seaking      68      2      False
# Gyarados     81      2      False

# %%
plt.bar(sorted_Attack.index,sorted_Attack['Attack'])
# Out:
# <BarContainer object of 6 artists>
